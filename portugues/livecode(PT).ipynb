# %% [markdown]
# # Vamos fazer um livecode!

# %% [markdown]
# Primeiro, vamos importar as bibliotecas de que vamos precisar

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Agora vamos definir a URL da página que estamos fazendo scraping, fazer um `request` para obter o HTML e analisá-lo (`parsing`).

# %%
url = "http://books.toscrape.com/index.html"
response = requests.get(url)
html = response.content
scraped = BeautifulSoup(html, 'html.parser')
